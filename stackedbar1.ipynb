# %%
import os
import csv
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

spendingpercapita_csv = ("cleanedpopbystate.csv")

# %%
spendingpercapita_df = pd.read_csv(spendingpercapita_csv)
spendingpercapita_df.head(20)
# Out:
#     year state  percapitaspend
# 0   2007    AL            5032
# 1   2007    CA            3366
# 2   2007    IA            3238
# 3   2007    KY            4299
# 4   2007    VT            3594
# 5   2007    WA            3890
# 6   2008    AL            7840
# 7   2008    CA            5883
# 8   2008    IA            5485
# 9   2008    KY            6851
# 10  2008    VT            6905
# 11  2008    WA            6322
# 12  2009    AL            7327
# 13  2009    CA            5477
# 14  2009    IA            5892
# 15  2009    KY            6337
# 16  2009    VT            7331
# 17  2009    WA            5716
# 18  2010    AL            9747
# 19  2010    CA            7028

# %%
clean_spendingpercapita_df = spendingpercapita_df.dropna(how="any")
clean_spendingpercapita_df.head()
# Out:
#    year state  percapitaspend
# 0  2007    AL            5032
# 1  2007    CA            3366
# 2  2007    IA            3238
# 3  2007    KY            4299
# 4  2007    VT            3594

# %%
#N = len(configs)
#N = 1
AL =(5032)
KY =(4299)
WA =(3890)
VT =(3594)
CA =(3366)
IA =(3228)
#configs=dataset[0]

# %%
N = 12
ind = np.arange(N)
width = 0.35
AL = (600,200,300,100,200,300,400,500,100,200,300,400)
KY = (400,150,250,100,200,300,400,500,100,200,300,400)
CA = (1500,1800,100,200,300,400,500,100,200,300,200,400)
WA = (300,400,600,100,200,300,400,500,100,200,300,400)
barsCA = np.add(AL,KY).tolist()
barsWA = np.add(barsCA,CA).tolist()
p1 = plt.bar(ind,AL,width, color="b")
p2 = plt.bar(ind,KY,width, bottom=AL, color='r')
p3 = plt.bar(ind,CA,width, bottom=barsCA, color='g')
p4 = plt.bar(ind,WA,width,bottom=barsWA,color='magenta')
years = ["2007", "2008", "2009", "2010", "2011", "2012", "2013", "2014", "2015", "2016", "2017", "2018"]

plt.ylabel("$ per Capita")
plt.title("Federal Spending per Capita")
plt.xticks(ind, years)
#plt.legend(p1([0], p2[0], p3[0], p4[0], p5[0], p6[0], "AL", "KY", "WA", "VT", "CA", "IA"))
plt.show()
