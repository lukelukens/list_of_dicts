# %%
import os
import csv
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

spendingpercapita_csv = ("cleanedpopbystate.csv")

# %%
spendingpercapita_df = pd.read_csv(spendingpercapita_csv)
spendingpercapita_df.head(20)
# Out:
#     year state  percapitaspend
# 0   2007    AL            5032
# 1   2007    CA            3366
# 2   2007    IA            3238
# 3   2007    KY            4299
# 4   2007    VT            3594
# 5   2007    WA            3890
# 6   2008    AL            7840
# 7   2008    CA            5883
# 8   2008    IA            5485
# 9   2008    KY            6851
# 10  2008    VT            6905
# 11  2008    WA            6322
# 12  2009    AL            7327
# 13  2009    CA            5477
# 14  2009    IA            5892
# 15  2009    KY            6337
# 16  2009    VT            7331
# 17  2009    WA            5716
# 18  2010    AL            9747
# 19  2010    CA            7028

# %%
clean_spendingpercapita_df = spendingpercapita_df.dropna(how="any")
clean_spendingpercapita_df.head()
# Out:
#    year state  percapitaspend
# 0  2007    AL            5032
# 1  2007    CA            3366
# 2  2007    IA            3238
# 3  2007    KY            4299
# 4  2007    VT            3594

# %%
N = 12
ind = np.arange(N)
width = 0.60

AL = (5032,7840,7327,9747,9249,9073,7390,12319,13226,13855,11794,10768)
KY = (4299,6851,6337,7110,7386,6896,7576,17121,19706,20095,20095,22920)
WA = (3890,6322,5716,7423,7631,7360,6492,7157,6859,7889,8204,8790)
VT = (3594,6905,7331,7138,7841,7927,7033,7596,8245,10707,8993,9141)
CA = (3366,5883,5477,7028,6835,6945,5548,6531,7339,7939,7909,8097)
IA = (3238,5485,5892,6303,6495,4356,5882,6459,7086,7464,7443,7869)
#barsCA = np.add(AL,KY).tolist()
#barsWA = np.add(barsCA,CA).tolist()
#barsVT = np.add(barsWA,WA).tolist()
#plt.bar(x, As)
#plt.bar(x, Bs, bottom = As)
#plt.bar(x, Cs, bottom = c_bottom)
#plt.bar(x, Ds, bottom = d_bottom)
#plt.bar(x, Fs, bottom = f_bottom)

barsKY = np.add(AL,KY).tolist()
barsWA = np.add(barsKY,WA).tolist()
barsVT = np.add(barsWA,VT).tolist()
barsCA = np.add(barsVT,CA).tolist()
#barsIA = np.add(barsCA,IA).tolist()

#barsKY = np.add()
#p1 = plt.bar(ind,AL,width, color="b")
#p2 = plt.bar(ind,KY,width, bottom=AL, color='r')
#p3 = plt.bar(ind,WA,width, bottom=barsKY, color='g')
#p4 = plt.bar(ind,VT,width, bottom=barsWA, color='magenta')
#p5 = plt.bar(ind,CA,width, bottom=barsVT, color='orange')
#p6 = plt.bar(ind,IA,width, bottom=barsCA, color='c')
wabottom = [AL,KY]
vtbottom = [AL,KY,WA]
cabottom = [AL,KY,WA,VT]
iabottom = [AL,KY,WA,VT,CA]

p1 = plt.bar(ind,AL,width,color='b')
p2 = plt.bar(ind,KY,width,bottom=AL,color='r')
p3 = plt.bar(ind,WA,width,bottom=barsKY,color='g')
p4 = plt.bar(ind,VT,width,bottom=barsWA,color='magenta')
p5 = plt.bar(ind,CA,width,bottom=barsVT,color='orange')
p6 = plt.bar(ind,IA,width,bottom=barsCA,color='c')
years = ["2007", "2008", "2009", "2010", "2011", "2012", "2013", "2014", "2015", "2016", "2017", "2018"]
plt.ylabel("$ per Capita")
plt.title("Federal Spending per Capita")
plt.xticks(ind, years, rotation=90)
plt.legend((p1[0], p2[0], p3[0], p4[0], p5[0], p6[0]), ("AL", "KY", "WA", "VT", "CA", "IA"))
           
#plt.legend(p1, p2, p3, p4, p5, p6, "AL" "KY", "WA", "VT", "CA", "IA")
           
plt.show()
